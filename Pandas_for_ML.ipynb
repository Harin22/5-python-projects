# %% [markdown]
# <a href="https://colab.research.google.com/github/Harin22/5-python-projects/blob/master/Pandas_for_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
series = pd.Series(["Carrot","onion","Potato","Tomato"])
print(series)
# Out:
# 0    Carrot
# 1     onion
# 2    Potato
# 3    Tomato
# dtype: object

# %%
df = pd.read_csv("california_housing_train.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-fbc9ca540c99> in <cell line: 1>()
# ----> 1 df = pd.read_csv("california_housing_train.csv")
#       2 print(df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("credits.csv")

# Display the DataFrame
display(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-32a1940d7dd1> in <cell line: 4>()
#       2
#       3 # Read the CSV file into a DataFrame
# ----> 4 df = pd.read_csv("credits.csv")
#       5
#       6 # Display the DataFrame
#
# ...

# %%
print(df.head)
display(df.head())
display(df.isnull())
display(df.isnull().sum())
# Out:
# <bound method NDFrame.head of        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
# 77800    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# ...

# %%
cinema = pd.read_csv("titles.csv")
#print("House price sample")
#display(housing_price.head())
#display(cinema[cinema['runtime'] > 30])
#display(cinema.sample(5))
after2019 = cinema[cinema['release_year']> 2019]
#display(after2019)

recent_score_based = after2019.sort_values(by="imdb_score" > 8, ascending=False)
display(recent_score_based)

#display(housing_price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5ee9d394bcfc> in <cell line: 1>()
# ----> 1 cinema = pd.read_csv("titles.csv")
#       2 #print("House price sample")
#       3 #display(housing_price.head())
#       4 #display(cinema[cinema['runtime'] > 30])
#       5 #display(cinema.sample(5))
#
# NameError: name 'pd' is not defined

# %%
recent_score_based = after2019[after2019['imdb_score'] > 8].sort_values(by="imdb_score", ascending=False)
display(recent_score_based)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6adc444049ff> in <cell line: 1>()
# ----> 1 recent_score_based = after2019[after2019['imdb_score'] > 8].sort_values(by="imdb_score", ascending=False)
#       2 display(recent_score_based)
#
# NameError: name 'after2019' is not defined

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("credits.csv")

# Display the DataFrame
display(df)
# Out:
#        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
# 77800    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# ...

# %%
cinema = pd.read_csv("titles.csv")

# Filter rows where 'release_year' is greater than 2019
after2019 = cinema[cinema['release_year'] > 2019]

# Filter rows where 'imdb_score' is greater than 8, then sort in descending order by 'imdb_score'
recent_score_based = after2019[after2019['imdb_score'] > 8].sort_values(by="imdb_score", ascending=False)

# Display the sorted DataFrame
display(recent_score_based)
# Out:
#             id                                     title   type  \
# 4771  tm996762                                     Major  MOVIE
# 3068   ts81120                            The Last Dance   SHOW
# 4718  ts222333                                    Arcane   SHOW
# 3271  tm853783  David Attenborough: A Life on Our Planet  MOVIE
# 3559  ts223192                         Hospital Playlist   SHOW
# ...        ...                                       ...    ...
# 3983  tm919106                            Rising Phoenix  MOVIE
# 4227  tm944631     The Three Deaths of Marisela Escobedo  MOVIE
# 4990  ts270405                       Pretend It's a City   SHOW
# 4934   ts94677                       Worst Roommate Ever   SHOW
# 5089  ts271321                               Beyond Evil   SHOW
#
#                                             description  release_year  \
# 4771  Based on the life of real-life Hero Major Sand...          2022
# ...

# %%
# Round the correlation matrix to two decimal places
correlation_rounded = cinema.round(2)
display(correlation_rounded)

# Optionally, visualize the correlation matrix using a heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

movies = pd.read_csv("TOP_100_IMDB_MOVIES[1].csv")
display(movies)

infos = movies.info()
#display(infos)

#if movies.duplicated().any():
 # print("\nyes there is a duplicate")
#else:
 # print("\nthere is no duplicate")

drop_duplicates = movies.drop_duplicates()
#display(drop_duplicates)

#display(movies.head())d#isplay(movies.tail())
#splay(movies.sample(5))
display(movies.describe())

renaming = movies.rename(columns={"rating": "IMDB rating"})
display(renaming)

updated_2 = renaming.rename(columns={"title" : "Movie names"})
updated_3 = updated_2.drop(columns = ["description"])

#update_4 = updated_3.dropna()


display(updated_3)
#display(updated_4)
# Out:
#     rank                                title  \
# 0     18  Spider-Man: Across the Spider-Verse
# 1     32                          Oppenheimer
# 2     77                                Joker
# 3     76                    Avengers: Endgame
# 4     37                             Parasite
# ..   ...                                  ...
# 95    99                         Citizen Kane
# 96    65                   The Great Dictator
# 97    49                         Modern Times
# 98    54                          City Lights
# 99   100                                    M
#
#                                           description  \
# 0   Miles Morales catapults across the Multiverse,...
# 1   The story of American scientist, J. Robert Opp...
# 2   A mentally troubled stand-up comedian embarks ...
# 3   After the devastating events of Avengers: Infi...
# 4   Greed and class discrimination threaten the ne...
# ..                                                ...
# ...

# %%
mvi = updated_3.explode('genre')
average_ratings = mvi.groupby('genre')['IMDB rating'].mean().sort_values(ascending=False)

# Plotting
plt.figure(figsize=(20, 10))
average_ratings.plot(kind="bar" , color='red')
plt.title('Average Ratings by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Rating of movies')
plt.xticks(rotation=45)
plt.grid(axis='y')
#plt.show()

# %%
import pandas as pd

df = pd.read_csv("housing.csv")
display(df)

update1 = df.dropna()
if df.equals(update1):
    print("\nthere is no missing data")
else:
    print("\nthere is missing data")

check_dupe = df.duplicated().any()

if check_dupe:
  drop_dup = df.drop_duplicates()
  print("duplicate dropped",drop_dup)
else:
  print("there is no duplicate")









dummy = pd.get_dummies(df['ocean_proximity'])
display(dummy)

island_count = (df["ocean_proximity"] == "ISLAND").sum()
print("\total island is ",island_count)

drop_island = df[df["ocean_proximity"] == "ISLAND"]
print("\island has been droped is being dropped")

missing_value = df.isnull().sum()
display("\nmissing value is ",missing_value)

null_values = df[[
    "longitude", "latitude", "housing_median_age", "total_rooms",
    "total_bedrooms", "population", "households",
    "median_income", "median_house_value", "ocean_proximity"]].isnull().any()
display("NULL VALUE RESULT", (null_values))


df["households"] = df["households"].fillna(df["households"].mean())
display("\nFilled value is:\n", df)



#display(drop_island)

#print("\nafter the data is being dropped")
#display(update1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("housing.csv")
display(df)

missed_value = df.isnull().sum()
if missed_value.any():
    print("there is missing value")
else:
    print("there is no missing value")

drop_median_age = df.dropna(subset=["housing_median_age"])
display(drop_median_age)


display(missed_value)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
dropping_one = df.drop(['population'], axis=1)
display(dropping_one)

new_column = df['automobiles'] = df['latitude'] - df['longitude']
display(new_column)


print("the location")
locate = df.loc[df['latitude'] == 37.88]
display(locate)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...
